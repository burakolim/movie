# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

class MovieRecommendationSystem:
    def __init__(self, movies_path, ratings_path):
        # Veri dosyalarını yüklerken hata kontrolü
        try:
            self.movies = pd.read_csv(movies_path)
            print(f"Movies data loaded. Shape: {self.movies.shape}")
        except FileNotFoundError:
            print("Movies file not found.")
            self.movies = pd.DataFrame()

        try:
            self.ratings = pd.read_csv(ratings_path)
            print(f"Ratings data loaded. Shape: {self.ratings.shape}")
        except FileNotFoundError:
            print("Ratings file not found.")
            self.ratings = pd.DataFrame()

        self.user_movie_matrix = None
        self.model = None

    def preprocess_data(self):
        # Kullanıcı-film matrisini oluştur
        if not self.ratings.empty:
            self.user_movie_matrix = self.ratings.pivot_table(index='userId', columns='movieId', values='rating', fill_value=0)
            print(f"User-movie matrix created. Shape: {self.user_movie_matrix.shape}")
        else:
            print("Ratings data is empty. Cannot create user-movie matrix.")
    
    def train_model(self):
        if self.user_movie_matrix is not None:
            self.model = NearestNeighbors(metric='cosine', algorithm='brute')
            self.model.fit(self.user_movie_matrix)
            print("Model trained successfully.")
        else:
            print("User-movie matrix is empty. Cannot train the model.")
    
    def get_user_based_recommendations(self, user_id, num_recommendations=5):
        # Kullanıcının film puanlarını al
        user_vector = self.user_movie_matrix.loc[user_id].values.reshape(1, -1)

        # En yakın komşuları bul
        distances, indices = self.model.kneighbors(user_vector, n_neighbors=6)

        # Benzer kullanıcıların izlediği filmleri bul
        similar_users = self.user_movie_matrix.index[indices.flatten()][1:]

        recommended_movies = []

        for similar_user in similar_users:
            # Benzer kullanıcının izlediği ve puanladığı filmleri al
            user_ratings = self.user_movie_matrix.loc[similar_user]
            recommended_movies.extend(user_ratings[user_ratings > 0].index.tolist())

        # Kullanıcının daha önce izlediği filmleri hariç tut
        watched_movies = self.user_movie_matrix.loc[user_id][self.user_movie_matrix.loc[user_id] > 0].index
        recommended_movies = [movie for movie in recommended_movies if movie not in watched_movies]

        # En çok önerilen filmleri sırala
        recommendations = pd.Series(recommended_movies).value_counts().sort_values(ascending=False)

        return recommendations.head(num_recommendations).index.tolist()

    def get_movie_based_recommendations(self, movie_id, num_recommendations=5):
        # Seçilen filmin türünü al
        movie_genres = self.movies[self.movies['movieId'] == movie_id]['genres'].values

        if len(movie_genres) == 0:
            print("Movie ID not found.")
            return []

        # Film bazlı öneri için film türlerini kullan
        movie_genres = movie_genres[0]
        similar_movies = self.movies[self.movies['genres'].str.contains(movie_genres, na=False)]

        # Seçilen film hariç öneri listesi oluştur
        similar_movies = similar_movies[similar_movies['movieId'] != movie_id]
        return similar_movies['movieId'].head(num_recommendations).tolist()

    def display_recommendations(self, recommended_movie_ids):
        if self.movies.empty:
            print("Movies data is empty. Cannot display recommendations.")
            return pd.DataFrame()

        if not recommended_movie_ids:
            print("No recommended movie IDs provided.")
            return pd.DataFrame()

        recommended_movies = self.movies[self.movies['movieId'].isin(recommended_movie_ids)]
        
        if recommended_movies.empty:
            print("No movies found for the provided movie IDs.")
            return pd.DataFrame()

        return recommended_movies[['title', 'genres']]

    def recommend_to_first_ten_users(self):
        all_recommendations = []
        
        # İlk 10 kullanıcıyı seç
        user_ids = self.user_movie_matrix.index[:10]  
        
        for user_id in user_ids:
            user_based_recommended_movie_ids = self.get_user_based_recommendations(user_id, num_recommendations=5)
            if user_based_recommended_movie_ids:
                recommended_movies_df = self.display_recommendations(user_based_recommended_movie_ids)
                if not recommended_movies_df.empty:
                    print(f"User ID: {user_id} (User-Based Recommendations)")
                    for _, row in recommended_movies_df.iterrows():
                        print(f"  - Title: {row['title']}, Genres: {row['genres']}")
                    for _, row in recommended_movies_df.iterrows():
                        all_recommendations.append({'userId': user_id, 'title': row['title'], 'genres': row['genres']})

                # Film bazlı öneri
                if user_based_recommended_movie_ids:
                    for movie_id in user_based_recommended_movie_ids:
                        movie_based_recommended_movie_ids = self.get_movie_based_recommendations(movie_id, num_recommendations=5)
                        if movie_based_recommended_movie_ids:
                            recommended_movies_df = self.display_recommendations(movie_based_recommended_movie_ids)
                            if not recommended_movies_df.empty:
                                print(f"User ID: {user_id} (Movie-Based Recommendations for Movie ID: {movie_id})")
                                for _, row in recommended_movies_df.iterrows():
                                    print(f"  - Title: {row['title']}, Genres: {row['genres']}")
                                for _, row in recommended_movies_df.iterrows():
                                    all_recommendations.append({'userId': user_id, 'title': row['title'], 'genres': row['genres']})
            else:
                print(f"No user-based recommendations for user ID: {user_id}")

        # Sonuçları DataFrame'e dönüştür
        recommendations_df = pd.DataFrame(all_recommendations)

        if not recommendations_df.empty:
            print("\nAll Recommendations for the first ten users:")
            print(recommendations_df)
        else:
            print("No recommendations generated for any of the first ten users.")

if __name__ == "__main__":
    movies_path = 'movies.csv'  # MovieLens filmleri
    ratings_path = 'ratings.csv'  # Kullanıcı puanları

    recommender = MovieRecommendationSystem(movies_path, ratings_path)
    recommender.preprocess_data()
    recommender.train_model()

    # İlk on kullanıcı için öneri alma
    recommender.recommend_to_first_ten_users()
# Out:
# Movies data loaded. Shape: (9125, 3)
# Ratings data loaded. Shape: (100004, 4)
# User-movie matrix created. Shape: (671, 9066)
# Model trained successfully.
# User ID: 1 (User-Based Recommendations)
#   - Title: Junior (1994), Genres: Comedy|Sci-Fi
#   - Title: Brady Bunch Movie, The (1995), Genres: Comedy
#   - Title: Space Jam (1996), Genres: Adventure|Animation|Children|Comedy|Fantasy|Sci-Fi
#   - Title: Highlander (1986), Genres: Action|Adventure|Fantasy
#   - Title: Beverly Hills Cop (1984), Genres: Action|Comedy|Crime|Drama
# User ID: 1 (Movie-Based Recommendations for Movie ID: 4085)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
# User ID: 1 (Movie-Based Recommendations for Movie ID: 256)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 1 (Movie-Based Recommendations for Movie ID: 1275)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 1 (Movie-Based Recommendations for Movie ID: 585)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 1 (Movie-Based Recommendations for Movie ID: 673)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 2 (User-Based Recommendations)
#   - Title: Stargate (1994), Genres: Action|Adventure|Sci-Fi
#   - Title: Ace Ventura: Pet Detective (1994), Genres: Comedy
#   - Title: True Lies (1994), Genres: Action|Adventure|Comedy|Romance|Thriller
#   - Title: Cliffhanger (1993), Genres: Action|Adventure|Thriller
#   - Title: Pretty Woman (1990), Genres: Comedy|Romance
# User ID: 2 (Movie-Based Recommendations for Movie ID: 344)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 2 (Movie-Based Recommendations for Movie ID: 597)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 2 (Movie-Based Recommendations for Movie ID: 434)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 2 (Movie-Based Recommendations for Movie ID: 380)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 2 (Movie-Based Recommendations for Movie ID: 316)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 3 (User-Based Recommendations)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jurassic Park (1993), Genres: Action|Adventure|Sci-Fi|Thriller
#   - Title: Shrek (2001), Genres: Adventure|Animation|Children|Comedy|Fantasy|Romance
#   - Title: Lord of the Rings: The Two Towers, The (2002), Genres: Adventure|Fantasy
#   - Title: Kill Bill: Vol. 2 (2004), Genres: Action|Drama|Thriller
# User ID: 3 (Movie-Based Recommendations for Movie ID: 1)
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 3 (Movie-Based Recommendations for Movie ID: 4306)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 3 (Movie-Based Recommendations for Movie ID: 480)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 3 (Movie-Based Recommendations for Movie ID: 7438)
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Sudden Death (1995), Genres: Action
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: American President, The (1995), Genres: Comedy|Drama|Romance
# User ID: 3 (Movie-Based Recommendations for Movie ID: 5952)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Balto (1995), Genres: Adventure|Animation|Children
# User ID: 4 (User-Based Recommendations)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Clerks (1994), Genres: Comedy
#   - Title: Mrs. Doubtfire (1993), Genres: Comedy|Drama
#   - Title: Back to the Future Part II (1989), Genres: Adventure|Comedy|Sci-Fi
#   - Title: Bug's Life, A (1998), Genres: Adventure|Animation|Children|Comedy
# User ID: 4 (Movie-Based Recommendations for Movie ID: 1)
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 4 (Movie-Based Recommendations for Movie ID: 223)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 4 (Movie-Based Recommendations for Movie ID: 2011)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 4 (Movie-Based Recommendations for Movie ID: 500)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 4 (Movie-Based Recommendations for Movie ID: 2355)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 5 (User-Based Recommendations)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Braveheart (1995), Genres: Action|Drama|War
#   - Title: Shawshank Redemption, The (1994), Genres: Crime|Drama
#   - Title: Twister (1996), Genres: Action|Adventure|Romance|Thriller
# User ID: 5 (Movie-Based Recommendations for Movie ID: 1)
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 5 (Movie-Based Recommendations for Movie ID: 736)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
# User ID: 5 (Movie-Based Recommendations for Movie ID: 2)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Balto (1995), Genres: Adventure|Animation|Children
#   - Title: Cutthroat Island (1995), Genres: Action|Adventure|Romance
# User ID: 5 (Movie-Based Recommendations for Movie ID: 110)
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Sudden Death (1995), Genres: Action
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: American President, The (1995), Genres: Comedy|Drama|Romance
# User ID: 5 (Movie-Based Recommendations for Movie ID: 318)
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: American President, The (1995), Genres: Comedy|Drama|Romance
#   - Title: Nixon (1995), Genres: Drama
#   - Title: Casino (1995), Genres: Crime|Drama
# User ID: 6 (User-Based Recommendations)
#   - Title: Star Wars: Episode IV - A New Hope (1977), Genres: Action|Adventure|Sci-Fi
#   - Title: Shawshank Redemption, The (1994), Genres: Crime|Drama
#   - Title: Star Wars: Episode V - The Empire Strikes Back (1980), Genres: Action|Adventure|Sci-Fi
#   - Title: Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981), Genres: Action|Adventure
#   - Title: Lord of the Rings: The Fellowship of the Ring, The (2001), Genres: Adventure|Fantasy
# User ID: 6 (Movie-Based Recommendations for Movie ID: 1196)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 6 (Movie-Based Recommendations for Movie ID: 260)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 6 (Movie-Based Recommendations for Movie ID: 1198)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 6 (Movie-Based Recommendations for Movie ID: 4993)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Balto (1995), Genres: Adventure|Animation|Children
# User ID: 6 (Movie-Based Recommendations for Movie ID: 318)
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: American President, The (1995), Genres: Comedy|Drama|Romance
#   - Title: Nixon (1995), Genres: Drama
#   - Title: Casino (1995), Genres: Crime|Drama
# User ID: 7 (User-Based Recommendations)
#   - Title: Pulp Fiction (1994), Genres: Comedy|Crime|Drama|Thriller
#   - Title: Fugitive, The (1993), Genres: Thriller
#   - Title: Rock, The (1996), Genres: Action|Adventure|Thriller
#   - Title: Aliens (1986), Genres: Action|Adventure|Horror|Sci-Fi
#   - Title: Alien (1979), Genres: Horror|Sci-Fi
# User ID: 7 (Movie-Based Recommendations for Movie ID: 1214)
#   - Title: Dracula: Dead and Loving It (1995), Genres: Comedy|Horror
#   - Title: Copycat (1995), Genres: Crime|Drama|Horror|Mystery|Thriller
#   - Title: Powder (1995), Genres: Drama|Sci-Fi
#   - Title: City of Lost Children, The (Cité des enfants perdus, La) (1995), Genres: Adventure|Drama|Fantasy|Mystery|Sci-Fi
#   - Title: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Genres: Mystery|Sci-Fi|Thriller
# User ID: 7 (Movie-Based Recommendations for Movie ID: 733)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 7 (Movie-Based Recommendations for Movie ID: 296)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
# User ID: 7 (Movie-Based Recommendations for Movie ID: 457)
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Money Train (1995), Genres: Action|Comedy|Crime|Drama|Thriller
#   - Title: Get Shorty (1995), Genres: Comedy|Crime|Thriller
#   - Title: Copycat (1995), Genres: Crime|Drama|Horror|Mystery|Thriller
# User ID: 7 (Movie-Based Recommendations for Movie ID: 1200)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 8 (User-Based Recommendations)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Truman Show, The (1998), Genres: Comedy|Drama|Sci-Fi
#   - Title: As Good as It Gets (1997), Genres: Comedy|Drama|Romance
#   - Title: Shrek (2001), Genres: Adventure|Animation|Children|Comedy|Fantasy|Romance
#   - Title: Pirates of the Caribbean: The Curse of the Black Pearl (2003), Genres: Action|Adventure|Comedy|Fantasy
# User ID: 8 (Movie-Based Recommendations for Movie ID: 1)
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 8 (Movie-Based Recommendations for Movie ID: 6539)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 8 (Movie-Based Recommendations for Movie ID: 1682)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 8 (Movie-Based Recommendations for Movie ID: 4306)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
# User ID: 8 (Movie-Based Recommendations for Movie ID: 1784)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Sabrina (1995), Genres: Comedy|Romance
# User ID: 9 (User-Based Recommendations)
#   - Title: Usual Suspects, The (1995), Genres: Crime|Mystery|Thriller
#   - Title: Braveheart (1995), Genres: Action|Drama|War
#   - Title: Apollo 13 (1995), Genres: Adventure|Drama|IMAX
#   - Title: Pulp Fiction (1994), Genres: Comedy|Crime|Drama|Thriller
#   - Title: L.A. Confidential (1997), Genres: Crime|Film-Noir|Mystery|Thriller
# User ID: 9 (Movie-Based Recommendations for Movie ID: 110)
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Sudden Death (1995), Genres: Action
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: American President, The (1995), Genres: Comedy|Drama|Romance
# User ID: 9 (Movie-Based Recommendations for Movie ID: 1617)
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Casino (1995), Genres: Crime|Drama
#   - Title: Money Train (1995), Genres: Action|Comedy|Crime|Drama|Thriller
#   - Title: Get Shorty (1995), Genres: Comedy|Crime|Thriller
# User ID: 9 (Movie-Based Recommendations for Movie ID: 296)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Grumpier Old Men (1995), Genres: Comedy|Romance
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Father of the Bride Part II (1995), Genres: Comedy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
# User ID: 9 (Movie-Based Recommendations for Movie ID: 50)
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Casino (1995), Genres: Crime|Drama
#   - Title: Money Train (1995), Genres: Action|Comedy|Crime|Drama|Thriller
#   - Title: Get Shorty (1995), Genres: Comedy|Crime|Thriller
# User ID: 9 (Movie-Based Recommendations for Movie ID: 150)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
# User ID: 10 (User-Based Recommendations)
#   - Title: Twelve Monkeys (a.k.a. 12 Monkeys) (1995), Genres: Mystery|Sci-Fi|Thriller
#   - Title: Terminator 2: Judgment Day (1991), Genres: Action|Sci-Fi
#   - Title: Silence of the Lambs, The (1991), Genres: Crime|Horror|Thriller
#   - Title: Saving Private Ryan (1998), Genres: Action|Drama|War
#   - Title: Star Wars: Episode I - The Phantom Menace (1999), Genres: Action|Adventure|Sci-Fi
# User ID: 10 (Movie-Based Recommendations for Movie ID: 2028)
#   - Title: Waiting to Exhale (1995), Genres: Comedy|Drama|Romance
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Sudden Death (1995), Genres: Action
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: American President, The (1995), Genres: Comedy|Drama|Romance
# User ID: 10 (Movie-Based Recommendations for Movie ID: 32)
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Money Train (1995), Genres: Action|Comedy|Crime|Drama|Thriller
#   - Title: Get Shorty (1995), Genres: Comedy|Crime|Thriller
#   - Title: Copycat (1995), Genres: Crime|Drama|Horror|Mystery|Thriller
# User ID: 10 (Movie-Based Recommendations for Movie ID: 2628)
#   - Title: Toy Story (1995), Genres: Adventure|Animation|Children|Comedy|Fantasy
#   - Title: Jumanji (1995), Genres: Adventure|Children|Fantasy
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Tom and Huck (1995), Genres: Adventure|Children
#   - Title: Sudden Death (1995), Genres: Action
# User ID: 10 (Movie-Based Recommendations for Movie ID: 589)
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: Sudden Death (1995), Genres: Action
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Cutthroat Island (1995), Genres: Action|Adventure|Romance
#   - Title: Money Train (1995), Genres: Action|Comedy|Crime|Drama|Thriller
# User ID: 10 (Movie-Based Recommendations for Movie ID: 593)
#   - Title: Heat (1995), Genres: Action|Crime|Thriller
#   - Title: GoldenEye (1995), Genres: Action|Adventure|Thriller
#   - Title: Dracula: Dead and Loving It (1995), Genres: Comedy|Horror
#   - Title: Casino (1995), Genres: Crime|Drama
#   - Title: Money Train (1995), Genres: Action|Comedy|Crime|Drama|Thriller
#
# All Recommendations for the first ten users:
#      userId                               title  \
# 0         1                       Junior (1994)
# 1         1       Brady Bunch Movie, The (1995)
# 2         1                    Space Jam (1996)
# 3         1                   Highlander (1986)
# 4         1            Beverly Hills Cop (1984)
# ..      ...                                 ...
# 295      10                         Heat (1995)
# 296      10                    GoldenEye (1995)
# 297      10  Dracula: Dead and Loving It (1995)
# 298      10                       Casino (1995)
# 299      10                  Money Train (1995)
#
#                                                 genres
# 0                                        Comedy|Sci-Fi
# 1                                               Comedy
# 2    Adventure|Animation|Children|Comedy|Fantasy|Sc...
# 3                             Action|Adventure|Fantasy
# 4                            Action|Comedy|Crime|Drama
# ..                                                 ...
# 295                              Action|Crime|Thriller
# 296                          Action|Adventure|Thriller
# 297                                      Comedy|Horror
# 298                                        Crime|Drama
# 299                 Action|Comedy|Crime|Drama|Thriller
#
# [300 rows x 3 columns]

# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors

class MovieRecommendationSystem:
    def __init__(self, movies_path, ratings_path):
        self.movies = pd.read_csv(movies_path)
        self.ratings = pd.read_csv(ratings_path)
        self.user_movie_matrix = None
        self.model = None

    def preprocess_data(self):
        # Kullanıcı-film matrisini oluştur
        self.user_movie_matrix = self.ratings.pivot_table(index='userId', columns='movieId', values='rating', fill_value=0)

    def train_model(self):
        # Nearest Neighbors modelini eğit
        self.model = NearestNeighbors(metric='cosine', algorithm='brute')
        self.model.fit(self.user_movie_matrix)

    def get_recommendations(self, user_id, num_recommendations=5):
        # Kullanıcının film puanlarını al
        user_vector = self.user_movie_matrix.loc[user_id].values.reshape(1, -1)

        # En yakın komşuları bul
        distances, indices = self.model.kneighbors(user_vector, n_neighbors=6)

        # Benzer kullanıcıların izlediği filmleri bul
        similar_users = self.user_movie_matrix.index[indices.flatten()][1:]

        recommended_movies = []

        for similar_user in similar_users:
            # Benzer kullanıcının izlediği ve puanladığı filmleri al
            user_ratings = self.user_movie_matrix.loc[similar_user]
            recommended_movies.extend(user_ratings[user_ratings > 0].index.tolist())  # Listeye ekle
            

        # Kullanıcının daha önce izlediği filmleri hariç tut
        watched_movies = self.user_movie_matrix.loc[user_id][self.user_movie_matrix.loc[user_id] > 0].index
        recommended_movies =  [movie for movie in recommended_movies if movie not in watched_movies]  # Liste filtrele

        # En çok önerilen filmleri sırala
        recommendations = pd.Series(recommended_movies).value_counts().sort_values(ascending=False)

        return recommendations.head(num_recommendations).index.tolist()

    def display_recommendations(self, recommended_movie_ids):
        recommended_movies = self.movies[self.movies['movieId'].isin(recommended_movie_ids)]
        return recommended_movies[['title', 'genres']]

if __name__ == "__main__":
    movies_path = 'movies.csv'  # MovieLens filmleri
    ratings_path = 'ratings.csv'  # Kullanıcı puanları

    recommender = MovieRecommendationSystem(movies_path, ratings_path)
    recommender.preprocess_data()
    recommender.train_model()

    # Tüm kullanıcılar için öneri alma
    all_recommendations = []
    user_ids = recommender.user_movie_matrix.index[:10]  # İlk 10 kullanıcıyı seç

    for user_id in user_ids:
        recommended_movie_ids = recommender.get_recommendations(user_id, num_recommendations=5)  # Her kullanıcı için 5 film öner
        recommended_movies_df = recommender.display_recommendations(recommended_movie_ids)

        for _, row in recommended_movies_df.iterrows():
            all_recommendations.append({'userId': user_id, 'title': row['title'], 'genres': row['genres']})

    # Sonuçları DataFrame'e dönüştür
    recommendations_df = pd.DataFrame(all_recommendations)

    # Önerileri yazdır
    print(recommendations_df)
# Out:
#     userId                                              title  \
# 0        1                                      Junior (1994)
# 1        1                      Brady Bunch Movie, The (1995)
# 2        1                                   Space Jam (1996)
# 3        1                                  Highlander (1986)
# 4        1                           Beverly Hills Cop (1984)
# 5        2                                    Stargate (1994)
# 6        2                  Ace Ventura: Pet Detective (1994)
# 7        2                                   True Lies (1994)
# 8        2                                 Cliffhanger (1993)
# 9        2                                Pretty Woman (1990)
# 10       3                                   Toy Story (1995)
# 11       3                               Jurassic Park (1993)
# 12       3                                       Shrek (2001)
# 13       3      Lord of the Rings: The Two Towers, The (2002)
# 14       3                           Kill Bill: Vol. 2 (2004)
# 15       4                                   Toy Story (1995)
# 16       4                                      Clerks (1994)
# 17       4                              Mrs. Doubtfire (1993)
# 18       4                  Back to the Future Part II (1989)
# 19       4                               Bug's Life, A (1998)
# 20       5                                   Toy Story (1995)
# 21       5                                     Jumanji (1995)
# 22       5                                  Braveheart (1995)
# 23       5                   Shawshank Redemption, The (1994)
# 24       5                                     Twister (1996)
# 25       6          Star Wars: Episode IV - A New Hope (1977)
# 26       6                   Shawshank Redemption, The (1994)
# 27       6  Star Wars: Episode V - The Empire Strikes Back...
# 28       6  Raiders of the Lost Ark (Indiana Jones and the...
# 29       6  Lord of the Rings: The Fellowship of the Ring,...
# 30       7                                Pulp Fiction (1994)
# 31       7                               Fugitive, The (1993)
# 32       7                                   Rock, The (1996)
# 33       7                                      Aliens (1986)
# 34       7                                       Alien (1979)
# 35       8                                   Toy Story (1995)
# 36       8                            Truman Show, The (1998)
# 37       8                          As Good as It Gets (1997)
# 38       8                                       Shrek (2001)
# 39       8  Pirates of the Caribbean: The Curse of the Bla...
# 40       9                         Usual Suspects, The (1995)
# 41       9                                  Braveheart (1995)
# 42       9                                   Apollo 13 (1995)
# 43       9                                Pulp Fiction (1994)
# 44       9                           L.A. Confidential (1997)
# 45      10          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 46      10                  Terminator 2: Judgment Day (1991)
# 47      10                   Silence of the Lambs, The (1991)
# 48      10                         Saving Private Ryan (1998)
# 49      10   Star Wars: Episode I - The Phantom Menace (1999)
#
#                                                genres
# 0                                       Comedy|Sci-Fi
# 1                                              Comedy
# 2   Adventure|Animation|Children|Comedy|Fantasy|Sc...
# 3                            Action|Adventure|Fantasy
# 4                           Action|Comedy|Crime|Drama
# 5                             Action|Adventure|Sci-Fi
# 6                                              Comedy
# 7            Action|Adventure|Comedy|Romance|Thriller
# 8                           Action|Adventure|Thriller
# 9                                      Comedy|Romance
# 10        Adventure|Animation|Children|Comedy|Fantasy
# 11                   Action|Adventure|Sci-Fi|Thriller
# 12  Adventure|Animation|Children|Comedy|Fantasy|Ro...
# 13                                  Adventure|Fantasy
# 14                              Action|Drama|Thriller
# 15        Adventure|Animation|Children|Comedy|Fantasy
# 16                                             Comedy
# 17                                       Comedy|Drama
# 18                            Adventure|Comedy|Sci-Fi
# 19                Adventure|Animation|Children|Comedy
# 20        Adventure|Animation|Children|Comedy|Fantasy
# 21                         Adventure|Children|Fantasy
# 22                                   Action|Drama|War
# 23                                        Crime|Drama
# 24                  Action|Adventure|Romance|Thriller
# 25                            Action|Adventure|Sci-Fi
# 26                                        Crime|Drama
# 27                            Action|Adventure|Sci-Fi
# 28                                   Action|Adventure
# 29                                  Adventure|Fantasy
# 30                        Comedy|Crime|Drama|Thriller
# 31                                           Thriller
# 32                          Action|Adventure|Thriller
# 33                     Action|Adventure|Horror|Sci-Fi
# 34                                      Horror|Sci-Fi
# 35        Adventure|Animation|Children|Comedy|Fantasy
# 36                                Comedy|Drama|Sci-Fi
# 37                               Comedy|Drama|Romance
# 38  Adventure|Animation|Children|Comedy|Fantasy|Ro...
# 39                    Action|Adventure|Comedy|Fantasy
# 40                             Crime|Mystery|Thriller
# 41                                   Action|Drama|War
# 42                               Adventure|Drama|IMAX
# 43                        Comedy|Crime|Drama|Thriller
# 44                   Crime|Film-Noir|Mystery|Thriller
# 45                            Mystery|Sci-Fi|Thriller
# 46                                      Action|Sci-Fi
# 47                              Crime|Horror|Thriller
# 48                                   Action|Drama|War
# 49                            Action|Adventure|Sci-Fi

# %%
import pandas as pd

if __name__ == "__main__":
    movies_path = 'movies.csv'  # MovieLens filmleri
    ratings_path = 'ratings.csv'  # Kullanıcı puanları

    recommender = MovieRecommendationSystem(movies_path, ratings_path)
    recommender.preprocess_data()

    # İlk 10 kullanıcıyı seç
    user_ids = recommender.user_movie_matrix.index[:10]

    # İlk 10 kullanıcının izlediği filmleri görüntüle
    for user_id in user_ids:
        user_ratings = recommender.user_movie_matrix.loc[user_id]
        watched_movies = user_ratings[user_ratings > 0]  # İzlenmiş filmleri al
        movie_titles = recommender.movies[recommender.movies['movieId'].isin(watched_movies.index)]['title']
        
        print(f"Kullanıcı {user_id} tarafından izlenen filmler:")
        print(movie_titles.tolist())
        print()  # Boş satır ekle
# Out:
# Kullanıcı 1 tarafından izlenen filmler:
# ['Dangerous Minds (1995)', 'Dumbo (1941)', 'Sleepers (1996)', 'Escape from New York (1981)', 'Cinema Paradiso (Nuovo cinema Paradiso) (1989)', 'Deer Hunter, The (1978)', 'Ben-Hur (1959)', 'Gandhi (1982)', "Dracula (Bram Stoker's Dracula) (1992)", 'Cape Fear (1991)', 'Star Trek: The Motion Picture (1979)', 'Beavis and Butt-Head Do America (1996)', 'French Connection, The (1971)', 'Tron (1982)', 'Gods Must Be Crazy, The (1980)', 'Willow (1988)', 'Antz (1998)', 'Fly, The (1986)', 'Time Bandits (1981)', 'Blazing Saddles (1974)']
#
# Kullanıcı 2 tarafından izlenen filmler:
# ['GoldenEye (1995)', 'Sense and Sensibility (1995)', 'Clueless (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)', 'Mighty Aphrodite (1995)', "Mr. Holland's Opus (1995)", 'Braveheart (1995)', 'Brothers McMullen, The (1995)', 'Apollo 13 (1995)', 'Batman Forever (1995)', 'Crimson Tide (1995)', 'Die Hard: With a Vengeance (1995)', 'First Knight (1995)', 'Net, The (1995)', 'Nine Months (1995)', 'Waterworld (1995)', 'Circle of Friends (1995)', 'Clerks (1994)', 'Disclosure (1994)', 'Ed Wood (1994)', 'Houseguest (1994)', 'Interview with the Vampire: The Vampire Chronicles (1994)', 'Little Women (1994)', 'Like Water for Chocolate (Como agua para chocolate) (1992)', 'Legends of the Fall (1994)', 'Madness of King George, The (1994)', "Mary Shelley's Frankenstein (Frankenstein) (1994)", 'Outbreak (1995)', 'Pulp Fiction (1994)', 'Quiz Show (1994)', 'Secret of Roan Inish, The (1994)', 'Santa Clause, The (1994)', 'Shallow Grave (1994)', 'While You Were Sleeping (1995)', 'Clear and Present Danger (1994)', 'Client, The (1994)', 'Forrest Gump (1994)', 'Four Weddings and a Funeral (1994)', 'Lion King, The (1994)', 'Mask, The (1994)', 'Naked Gun 33 1/3: The Final Insult (1994)', 'Paper, The (1994)', 'Reality Bites (1994)', 'Speed (1994)', 'Wolf (1994)', 'Highlander III: The Sorcerer (a.k.a. Highlander: The Final Dimension) (1994)', 'Addams Family Values (1993)', 'Firm, The (1993)', 'Fugitive, The (1993)', 'Englishman Who Went Up a Hill But Came Down a Mountain, The (1995)', 'In the Line of Fire (1993)', 'Jurassic Park (1993)', 'Last Action Hero (1993)', 'Much Ado About Nothing (1993)', 'Mrs. Doubtfire (1993)', 'Philadelphia (1993)', 'Piano, The (1993)', 'Remains of the Day, The (1993)', "Schindler's List (1993)", 'Sirens (1994)', 'Sleepless in Seattle (1993)', 'Threesome (1994)', 'Nightmare Before Christmas, The (1993)', 'Three Musketeers, The (1993)', 'Brady Bunch Movie, The (1995)', 'Home Alone (1990)', 'Ghost (1990)', 'Aladdin (1992)', 'Terminator 2: Judgment Day (1991)', 'Dances with Wolves (1990)', 'Batman (1989)', 'Silence of the Lambs, The (1991)', 'Aristocats, The (1970)', 'James and the Giant Peach (1996)', 'Wallace & Gromit: The Best of Aardman Animation (1996)']
#
# Kullanıcı 3 tarafından izlenen filmler:
# ['Indian in the Cupboard, The (1995)', 'Braveheart (1995)', 'Heavenly Creatures (1994)', 'Major Payne (1995)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Flintstones, The (1994)', 'Forrest Gump (1994)', 'Speed (1994)', "Schindler's List (1993)", 'Aladdin (1992)', 'Batman (1989)', 'Silence of the Lambs, The (1991)', 'Beauty and the Beast (1991)', 'Twister (1996)', 'Trainspotting (1996)', 'Bound (1996)', 'Princess Bride, The (1987)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Harold and Maude (1971)', 'Fried Green Tomatoes (1991)', 'Young Guns (1988)', 'Men in Black (a.k.a. MIB) (1997)', 'Titanic (1997)', 'Fear and Loathing in Las Vegas (1998)', 'Saving Private Ryan (1998)', 'Happiness (1998)', 'Pet Sematary (1989)', 'Big Daddy (1999)', 'Summer of Sam (1999)', 'Ghostbusters (a.k.a. Ghost Busters) (1984)', 'Sixth Sense, The (1999)', 'Stir of Echoes (1999)', 'American Beauty (1999)', 'Fight Club (1999)', 'Encino Man (1992)', 'Frequency (2000)', 'Requiem for a Dream (2000)', 'Spider-Man (2002)', 'Bowling for Columbine (2002)', 'Finding Nemo (2003)', 'Lord of the Rings: The Return of the King, The (2003)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Fahrenheit 9/11 (2004)', 'Spider-Man 2 (2004)', 'Daria: Is It Fall Yet? (2000)', 'V for Vendetta (2006)', 'Flags of Our Fathers (2006)', 'Letters from Iwo Jima (2006)', 'Dark Knight, The (2008)', 'White Stripes Under Great White Northern Lights, The (2009)']
#
# Kullanıcı 4 tarafından izlenen filmler:
# ['GoldenEye (1995)', 'Babe (1995)', 'Rumble in the Bronx (Hont faan kui) (1995)', 'Birdcage, The (1996)', 'Batman Forever (1995)', 'Judge Dredd (1995)', 'Net, The (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Only You (1994)', 'Pulp Fiction (1994)', 'Star Trek: Generations (1994)', 'Clear and Present Danger (1994)', 'Forrest Gump (1994)', 'Four Weddings and a Funeral (1994)', 'Lion King, The (1994)', 'Mask, The (1994)', 'True Lies (1994)', 'Addams Family Values (1993)', "Carlito's Way (1993)", 'Cliffhanger (1993)', 'Coneheads (1993)', 'Dave (1993)', 'Demolition Man (1993)', 'Hard Target (1993)', 'Jurassic Park (1993)', 'Blade Runner (1982)', 'Aladdin (1992)', 'Terminator 2: Judgment Day (1991)', 'Dances with Wolves (1990)', 'Snow White and the Seven Dwarfs (1937)', 'Pinocchio (1940)', 'Heavy Metal (1981)', 'Aristocats, The (1970)', 'Godfather, The (1972)', 'Vertigo (1958)', 'Some Like It Hot (1959)', 'Maltese Falcon, The (1941)', 'Wizard of Oz, The (1939)', 'Herbie Rides Again (1974)', 'Shaggy Dog, The (1959)', 'Cinderella (1950)', 'Mary Poppins (1964)', "Pete's Dragon (1977)", 'Bedknobs and Broomsticks (1971)', 'Alice in Wonderland (1951)', 'Fox and the Hound, The (1981)', 'Die Hard (1988)', 'Willy Wonka & the Chocolate Factory (1971)', 'Fish Called Wanda, A (1988)', 'Reservoir Dogs (1992)', 'E.T. the Extra-Terrestrial (1982)', 'Return of the Pink Panther, The (1975)', 'Abyss, The (1989)', 'Monty Python and the Holy Grail (1975)', "Cheech and Chong's Up in Smoke (1978)", 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Aliens (1986)', 'Clockwork Orange, A (1971)', 'Apocalypse Now (1979)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Goodfellas (1990)', 'Alien (1979)', 'Psycho (1960)', 'Blues Brothers, The (1980)', 'Full Metal Jacket (1987)', 'Amadeus (1984)', 'Annie Hall (1977)', 'Terminator, The (1984)', 'Rosencrantz and Guildenstern Are Dead (1990)', 'Better Off Dead... (1985)', 'Shining, The (1980)', 'Stand by Me (1986)', 'Groundhog Day (1993)', 'Back to the Future (1985)', 'Young Frankenstein (1974)', 'Fantasia (1940)', 'Heathers (1989)', 'This Is Spinal Tap (1984)', 'Indiana Jones and the Last Crusade (1989)', 'Pink Floyd: The Wall (1982)', 'When Harry Met Sally... (1989)', 'Believers, The (1987)', 'Blob, The (1958)', 'Cape Fear (1962)', 'Star Trek: First Contact (1996)', 'Star Trek: The Motion Picture (1979)', 'Star Trek VI: The Undiscovered Country (1991)', 'Star Trek II: The Wrath of Khan (1982)', 'Star Trek IV: The Voyage Home (1986)', 'Batman Returns (1992)', 'Grease (1978)', 'Jaws (1975)', 'Jaws 2 (1978)', 'Sneakers (1992)', 'Lost World: Jurassic Park, The (1997)', 'Men in Black (a.k.a. MIB) (1997)', 'Stripes (1981)', 'Witness (1985)', 'Wild Things (1998)', 'Mr. Nice Guy (Yat goh ho yan) (1997)', 'Armageddon (1998)', 'Lethal Weapon 4 (1998)', 'French Connection, The (1971)', 'Rocky (1976)', 'Rain Man (1988)', 'Labyrinth (1986)', 'Breakfast Club, The (1985)', 'Poltergeist (1982)', 'Lethal Weapon (1987)', 'Lethal Weapon 3 (1992)', 'Gremlins (1984)', 'Goonies, The (1985)', 'Freaky Friday (1977)', 'Bambi (1942)', 'Dangerous Liaisons (1988)', 'Dune (1984)', 'Black Cauldron, The (1985)', 'Black Hole, The (1979)', 'Flight of the Navigator (1986)', 'Honey, I Shrunk the Kids (1989)', 'Roger & Me (1989)', 'Jungle Book, The (1967)', 'Lady and the Tramp (1955)', 'Little Mermaid, The (1989)', '101 Dalmatians (One Hundred and One Dalmatians) (1961)', 'One Magic Christmas (1985)', 'Peter Pan (1953)', 'Return from Witch Mountain (1978)', 'Rocketeer, The (1991)', 'Sleeping Beauty (1959)', 'Splash (1984)', 'Steamboat Willie (1928)', 'Tron (1982)', 'Jerk, The (1979)', "Dead Men Don't Wear Plaid (1982)", 'Outsiders, The (1983)', 'Indiana Jones and the Temple of Doom (1984)', 'Addams Family, The (1991)', 'Dark Crystal, The (1982)', 'American Tail, An (1986)', 'Legend (1985)', 'Sixteen Candles (1984) ...
#
# Kullanıcı 5 tarafından izlenen filmler:
# ['Grumpier Old Men (1995)', 'Clueless (1995)', 'Happy Gilmore (1996)', 'Birdcage, The (1996)', 'Apollo 13 (1995)', 'Dumb & Dumber (Dumb and Dumber) (1994)', 'Miracle on 34th Street (1994)', 'Ace Ventura: Pet Detective (1994)', 'Forrest Gump (1994)', 'Lion King, The (1994)', 'Mask, The (1994)', 'Speed (1994)', 'Dave (1993)', 'Mrs. Doubtfire (1993)', 'Home Alone (1990)', 'Aladdin (1992)', 'Beauty and the Beast (1991)', 'Pretty Woman (1990)', 'Nutty Professor, The (1996)', 'Godfather, The (1972)', 'Vertigo (1958)', 'Wizard of Oz, The (1939)', 'Cinderella (1950)', 'Sound of Music, The (1965)', "One Flew Over the Cuckoo's Nest (1975)", 'Godfather: Part II, The (1974)', 'Graduate, The (1967)', 'When Harry Met Sally... (1989)', 'Grease (1978)', 'Jerry Maguire (1996)', 'Liar Liar (1997)', 'Lost World: Jurassic Park, The (1997)', 'Truman Show, The (1998)', 'Titanic (1997)', 'Wedding Singer, The (1998)', 'As Good as It Gets (1997)', "There's Something About Mary (1998)", 'Rain Man (1988)', 'Breakfast Club, The (1985)', 'Exorcist, The (1973)', 'Godfather: Part III, The (1990)', 'Little Mermaid, The (1989)', 'Rush Hour (1998)', 'Antz (1998)', "Bug's Life, A (1998)", "You've Got Mail (1998)", 'Office Space (1999)', 'Austin Powers: The Spy Who Shagged Me (1999)', 'Big Daddy (1999)', 'American Pie (1999)', 'Sixth Sense, The (1999)', 'Bowfinger (1999)', "Ferris Bueller's Day Off (1986)", 'Being John Malkovich (1999)', 'Toy Story 2 (1999)', 'Talented Mr. Ripley, The (1999)', 'Erin Brockovich (2000)', 'Patriot, The (2000)', 'Almost Famous (2000)', 'Meet the Parents (2000)', 'Chocolat (2000)', 'What Women Want (2000)', 'Cast Away (2000)', 'Miss Congeniality (2000)', 'Shrek (2001)', 'Moulin Rouge (2001)', 'Legally Blonde (2001)', 'American Pie 2 (2001)', "Ocean's Eleven (2001)", 'Beautiful Mind, A (2001)', 'Panic Room (2002)', 'My Big Fat Greek Wedding (2002)', 'Spider-Man (2002)', 'Road to Perdition (2002)', 'Bowling for Columbine (2002)', 'Ring, The (2002)', 'Harry Potter and the Chamber of Secrets (2002)', 'Pianist, The (2002)', 'Bend It Like Beckham (2002)', 'Bruce Almighty (2003)', 'Finding Nemo (2003)', '28 Days Later (2002)', 'Lost in Translation (2003)', 'Love Actually (2003)', 'Napoleon Dynamite (2004)', 'Super Size Me (2004)', 'Fahrenheit 9/11 (2004)', 'Spider-Man 2 (2004)', 'I, Robot (2004)', 'Million Dollar Baby (2004)', 'Hotel Rwanda (2004)', 'Charlie and the Chocolate Factory (2005)', 'Crash (2004)', 'Mr. & Mrs. Smith (2005)', 'Wedding Crashers (2005)', '40-Year-Old Virgin, The (2005)', 'Walk the Line (2005)', 'Chronicles of Narnia: The Lion, the Witch and the Wardrobe, The (2005)', 'King Kong (2005)', 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan (2006)']
#
# Kullanıcı 6 tarafından izlenen filmler:
# ['Taxi Driver (1976)', 'Casper (1995)', 'Judge Dredd (1995)', 'Léon: The Professional (a.k.a. The Professional) (Léon) (1994)', 'Pinocchio (1940)', 'Vertigo (1958)', 'Lawrence of Arabia (1962)', 'Bridge on the River Kwai, The (1957)', 'Stand by Me (1986)', 'Cool Hand Luke (1967)', 'Heathers (1989)', 'Sling Blade (1996)', 'Chasing Amy (1997)', 'Jackal, The (1997)', 'Wag the Dog (1997)', 'Deep Impact (1998)', 'X-Files: Fight the Future, The (1998)', 'Lethal Weapon 2 (1989)', 'Seven Samurai (Shichinin no samurai) (1954)', "'burbs, The (1989)", 'Beetlejuice (1988)', 'Office Space (1999)', "Logan's Run (1976)", 'Planet of the Apes (1968)', 'Matrix, The (1999)', 'Rocky Horror Picture Show, The (1975)', 'Run Lola Run (Lola rennt) (1998)', 'Mystery Men (1999)', 'Iron Giant, The (1999)', 'Three Kings (1999)', 'Dogma (1999)', 'Toy Story 2 (1999)', 'Pitch Black (2000)', 'Chicken Run (2000)', 'Ghost World (2001)', 'Vanilla Sky (2001)', 'Lord of the Rings: The Two Towers, The (2002)', 'Hero (Ying xiong) (2002)', 'Lord of the Rings: The Return of the King, The (2003)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Harry Potter and the Prisoner of Azkaban (2004)', 'Spider-Man 2 (2004)', 'Garden State (2004)', 'Shaun of the Dead (2004)']
#
# Kullanıcı 7 tarafından izlenen filmler:
# ['Toy Story (1995)', 'GoldenEye (1995)', 'Get Shorty (1995)', 'Dangerous Minds (1995)', 'Babe (1995)', 'Cry, the Beloved Country (1995)', 'Happy Gilmore (1996)', 'Braveheart (1995)', 'Rumble in the Bronx (Hont faan kui) (1995)', 'Birdcage, The (1996)', 'Rob Roy (1995)', 'Strange Days (1995)', 'Walk in the Clouds, A (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Madness of King George, The (1994)', 'Stargate (1994)', 'Shawshank Redemption, The (1994)', 'Star Trek: Generations (1994)', 'Tommy Boy (1995)', 'Adventures of Priscilla, Queen of the Desert, The (1994)', 'Flintstones, The (1994)', 'Forrest Gump (1994)', 'Four Weddings and a Funeral (1994)', 'Lion King, The (1994)', 'Mask, The (1994)', 'Speed (1994)', 'True Lies (1994)', 'Jurassic Park (1993)', 'Mrs. Doubtfire (1993)', 'Shadowlands (1993)', 'Sleepless in Seattle (1993)', 'Blade Runner (1982)', 'Nightmare Before Christmas, The (1993)', 'Aladdin (1992)', 'Terminator 2: Judgment Day (1991)', 'Dances with Wolves (1990)', 'Batman (1989)', 'Snow White and the Seven Dwarfs (1937)', 'Beauty and the Beast (1991)', 'Heavy Metal (1981)', 'Mystery Science Theater 3000: The Movie (1996)', 'Truth About Cats & Dogs, The (1996)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Craft, The (1996)', 'Twister (1996)', 'Barb Wire (1996)', 'Wallace & Gromit: A Close Shave (1995)', 'Independence Day (a.k.a. ID4) (1996)', 'Eraser (1996)', '2001: A Space Odyssey (1968)', 'Die Hard (1988)', 'Willy Wonka & the Chocolate Factory (1971)', 'Fish Called Wanda, A (1988)', "Monty Python's Life of Brian (1979)", 'E.T. the Extra-Terrestrial (1982)', 'Return of the Pink Panther, The (1975)', 'Escape from New York (1981)', 'Monty Python and the Holy Grail (1975)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Blues Brothers, The (1980)', 'Grand Day Out with Wallace and Gromit, A (1989)', 'Amadeus (1984)', 'Right Stuff, The (1983)', 'Terminator, The (1984)', 'Glory (1989)', 'Back to the Future (1985)', 'Highlander (1986)', 'Young Frankenstein (1974)', 'Ben-Hur (1959)', 'This Is Spinal Tap (1984)', 'Indiana Jones and the Last Crusade (1989)', 'Pink Floyd: The Wall (1982)', 'Field of Dreams (1989)', 'When Harry Met Sally... (1989)', 'Mirror Has Two Faces, The (1996)', 'Star Trek: The Motion Picture (1979)', 'Star Trek VI: The Undiscovered Country (1991)', 'Star Trek V: The Final Frontier (1989)', 'Star Trek II: The Wrath of Khan (1982)', 'Star Trek III: The Search for Spock (1984)', 'Star Trek IV: The Voyage Home (1986)', 'Raising Arizona (1987)', 'Beavis and Butt-Head Do America (1996)', 'Last of the Mohicans, The (1992)']
#
# Kullanıcı 8 tarafından izlenen filmler:
# ['Twelve Monkeys (a.k.a. 12 Monkeys) (1995)', 'To Die For (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Usual Suspects, The (1995)', 'Braveheart (1995)', 'Star Wars: Episode IV - A New Hope (1977)', 'Nell (1994)', 'Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Forrest Gump (1994)', 'Fugitive, The (1993)', 'Robin Hood: Men in Tights (1993)', 'Rudy (1993)', "Schindler's List (1993)", 'So I Married an Axe Murderer (1993)', 'Terminator 2: Judgment Day (1991)', 'Silence of the Lambs, The (1991)', 'Primal Fear (1996)', 'Time to Kill, A (1996)', 'Godfather, The (1972)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Psycho (1960)', 'Amadeus (1984)', 'Shining, The (1980)', 'Stand by Me (1986)', 'Groundhog Day (1993)', 'Back to the Future (1985)', 'Indiana Jones and the Last Crusade (1989)', 'Field of Dreams (1989)', 'Sling Blade (1996)', 'Jaws (1975)', 'Jerry Maguire (1996)', 'Grosse Pointe Blank (1997)', 'Con Air (1997)', 'L.A. Confidential (1997)', 'Game, The (1997)', 'Witness (1985)', 'Good Will Hunting (1997)', 'Fallen (1998)', 'Wedding Singer, The (1998)', 'Deep Impact (1998)', 'Rain Man (1988)', 'Saving Private Ryan (1998)', 'Splash (1984)', 'Secret of NIMH, The (1982)', 'Untouchables, The (1987)', 'My Cousin Vinny (1992)', 'Life Is Beautiful (La Vita è bella) (1997)', 'American History X (1998)', 'Enemy of the State (1998)', "Christmas Vacation (National Lampoon's Christmas Vacation) (1989)", 'Office Space (1999)', 'Matrix, The (1999)', 'Ghostbusters (a.k.a. Ghost Busters) (1984)', 'Sixth Sense, The (1999)', 'Bowfinger (1999)', 'Airplane! (1980)', 'Big (1988)', 'Christmas Story, A (1983)', 'Stir of Echoes (1999)', 'American Beauty (1999)', "Ferris Bueller's Day Off (1986)", 'Fight Club (1999)', 'Green Mile, The (1999)', 'Gladiator (2000)', 'Remember the Titans (2000)', 'Meet the Parents (2000)', 'Crouching Tiger, Hidden Dragon (Wo hu cang long) (2000)', 'Snatch (2000)', 'Finding Forrester (2000)', 'Traffic (2000)', 'Memento (2000)', 'Scarface (1983)', 'Score, The (2001)', 'Monsters, Inc. (2001)', "Harry Potter and the Sorcerer's Stone (a.k.a. Harry Potter and the Philosopher's Stone) (2001)", "Ocean's Eleven (2001)", "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Beautiful Mind, A (2001)', 'The Count of Monte Cristo (2002)', 'Star Wars: Episode II - Attack of the Clones (2002)', 'Minority Report (2002)', 'Road to Perdition (2002)', 'Red Dragon (2002)', 'Strange Brew (1983)', 'Bowling for Columbine (2002)', 'Lord of the Rings: The Two Towers, The (2002)', 'Catch Me If You Can (2002)', 'Finding Nemo (2003)', 'Italian Job, The (2003)', 'Mystic River (2003)', 'Kill Bill: Vol. 1 (2003)', 'Runaway Jury (2003)', 'Last Samurai, The (2003)', 'Lord of the Rings: The Return of the King, The (2003)', 'Eternal Sunshine of the Spotless Mind (2004)', 'Kill Bill: Vol. 2 (2004)', 'Notebook, The (2004)', 'Garden State (2004)', 'Motorcycle Diaries, The (Diarios de motocicleta) (2004)', 'Shaun of the Dead (2004)', 'Sin City (2005)', 'Crash (2004)', 'Star Wars: Episode III - Revenge of the Sith (2005)', 'Batman Begins (2005)', 'Wedding Crashers (2005)', 'Syriana (2005)', 'Walk the Line (2005)', 'Rumor Has It... (2005)', 'Annapolis (2006)', 'Firewall (2006)', 'Failure to Launch (2006)']
#
# Kullanıcı 9 tarafından izlenen filmler:
# ['Toy Story (1995)', 'Sense and Sensibility (1995)', 'Othello (1995)', 'Dead Man Walking (1995)', 'Seven (a.k.a. Se7en) (1995)', 'Shawshank Redemption, The (1994)', 'Much Ado About Nothing (1993)', 'Remains of the Day, The (1993)', "Schindler's List (1993)", 'Shadowlands (1993)', 'Silence of the Lambs, The (1991)', 'Fargo (1996)', 'Rock, The (1996)', "William Shakespeare's Romeo + Juliet (1996)", 'Enchanted April (1992)', 'Shine (1996)', 'Sling Blade (1996)', 'Hamlet (1996)', 'Addicted to Love (1997)', 'Contact (1997)', 'Sliding Doors (1998)', 'Truman Show, The (1998)', 'Good Will Hunting (1997)', 'Titanic (1997)', 'As Good as It Gets (1997)', 'Saving Private Ryan (1998)', 'Ever After: A Cinderella Story (1998)', 'Dark Crystal, The (1982)', 'My Blue Heaven (1990)', 'Few Good Men, A (1992)', 'Rush Hour (1998)', 'Ronin (1998)', 'Edward Scissorhands (1990)', 'Antz (1998)', 'My Cousin Vinny (1992)', 'Simple Plan, A (1998)', 'Shakespeare in Love (1998)', 'Thin Red Line, The (1998)', 'Payback (1999)', 'October Sky (1999)', 'Analyze This (1999)', 'Matrix, The (1999)', 'Star Wars: Episode I - The Phantom Menace (1999)', 'Sixth Sense, The (1999)', 'Yellow Submarine (1968)']
#
# Kullanıcı 10 tarafından izlenen filmler:
# ['Usual Suspects, The (1995)', 'Addiction, The (1995)', 'Shawshank Redemption, The (1994)', 'Ace Ventura: Pet Detective (1994)', 'Adventures of Priscilla, Queen of the Desert, The (1994)', 'Batman (1989)', 'Cemetery Man (Dellamorte Dellamore) (1994)', 'Die Hard (1988)', 'Reservoir Dogs (1992)', 'Top Gun (1986)', 'Abyss, The (1989)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)', 'Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)', 'Aliens (1986)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Blues Brothers, The (1980)', 'Terminator, The (1984)', 'Indiana Jones and the Last Crusade (1989)', 'Sling Blade (1996)', 'Hearts and Minds (1996)', 'Absolute Power (1997)', 'Anaconda (1997)', 'My Own Private Idaho (1991)', 'Alien: Resurrection (1997)', 'Good Will Hunting (1997)', 'Sweet Hereafter, The (1997)', 'Almost Heroes (1998)', "There's Something About Mary (1998)", 'L.A. Story (1991)', 'Runaway Train (1985)', 'Romancing the Stone (1984)', 'Rocky III (1982)', 'Analyze This (1999)', 'Matrix, The (1999)', '13th Warrior, The (1999)', "Astronaut's Wife, The (1999)", 'Stigmata (1999)', 'Stir of Echoes (1999)', 'Double Jeopardy (1999)', 'Three Kings (1999)', 'Superstar (1999)', 'Hairspray (1988)', 'House on Haunted Hill (1999)', 'Bone Collector, The (1999)', 'Drugstore Cowboy (1989)']

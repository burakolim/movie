# %%
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

class MovieRecommendationSystem:
    def __init__(self, movies_path, ratings_path, tags_path):
        # Veri dosyalarını yüklerken hata kontrolü
        try:
            self.movies = pd.read_csv(movies_path)
            print(f"Movies data loaded. Shape: {self.movies.shape}")
        except FileNotFoundError:
            print("Movies file not found.")
            self.movies = pd.DataFrame()

        try:
            self.ratings = pd.read_csv(ratings_path)
            print(f"Ratings data loaded. Shape: {self.ratings.shape}")
        except FileNotFoundError:
            print("Ratings file not found.")
            self.ratings = pd.DataFrame()

        try:
            self.tags = pd.read_csv(tags_path)
            print(f"Tags data loaded. Shape: {self.tags.shape}")
        except FileNotFoundError:
            print("Tags file not found.")
            self.tags = pd.DataFrame()

        self.user_movie_matrix = None
        self.model = None
        self.tag_similarity = None
        self.genre_similarity = None

    def preprocess_data(self):
        # Kullanıcı-film matrisini oluştur
        if not self.ratings.empty:
            self.user_movie_matrix = self.ratings.pivot_table(index='userId', columns='movieId', values='rating', fill_value=0)
            print(f"User-movie matrix created. Shape: {self.user_movie_matrix.shape}")
        else:
            print("Ratings data is empty. Cannot create user-movie matrix.")
        
        # Etiketleri ve filmleri birleştir
        if not self.tags.empty:
            movie_tags_df = self.tags.groupby('movieId')['tag'].apply(lambda x: ' '.join(x)).reset_index()
            self.movies = pd.merge(self.movies, movie_tags_df, on='movieId', how='left')
            self.movies['tag'] = self.movies['tag'].fillna('')

            # TF-IDF matrisi oluştur (tag bazlı öneri için)
            tfidf = TfidfVectorizer(stop_words='english')
            tfidf_matrix = tfidf.fit_transform(self.movies['tag'])

            # Cosine similarity hesapla (tag bazlı)
            self.tag_similarity = cosine_similarity(tfidf_matrix)
            print("Tag-based similarity matrix created.")
        else:
            print("Tags data is empty. Cannot calculate tag similarity.")

        # Tür bilgisi için TF-IDF benzeri bir yaklaşımla tür benzerliğini hesaplama
        if 'genres' in self.movies.columns:
            tfidf_genres = TfidfVectorizer(tokenizer=lambda x: x.split('|'), stop_words='english')
            tfidf_genres_matrix = tfidf_genres.fit_transform(self.movies['genres'])
            
            # Cosine similarity hesapla (genre bazlı)
            self.genre_similarity = cosine_similarity(tfidf_genres_matrix)
            print("Genre-based similarity matrix created.")
        else:
            print("Genres data is missing. Cannot calculate genre similarity.")

    def train_model(self):
        if self.user_movie_matrix is not None:
            self.model = NearestNeighbors(metric='cosine', algorithm='brute')
            self.model.fit(self.user_movie_matrix)
            print("Model trained successfully.")
        else:
            print("User-movie matrix is empty. Cannot train the model.")
    
    def get_user_based_recommendations(self, user_id, num_recommendations=5):
        # Kullanıcıya dayalı öneri almak için modeli kullan
        if self.model is None:
            print("Model is not trained yet.")
            return []
        
        user_vector = self.user_movie_matrix.loc[user_id].values.reshape(1, -1)
        distances, indices = self.model.kneighbors(user_vector, n_neighbors=num_recommendations + 1)
        
        # İlk öğe kendi kullanıcı olduğundan onu hariç tut
        recommended_user_ids = self.user_movie_matrix.index[indices.flatten()[1:]].tolist()
        return recommended_user_ids

    def get_weighted_recommendations(self, movie_id, genre_weight=0.7, tag_weight=0.3, num_recommendations=5):
        # Belirtilen movie_id'ye göre genre ve tag benzerliklerini ağırlıklı olarak hesapla

        # Tür ve etiket benzerliklerini bul
        if self.genre_similarity is None or self.tag_similarity is None:
            print("Genre or tag similarity not available.")
            return []

        # movie_id'nin geçerli olup olmadığını kontrol et
        if movie_id not in self.movies['movieId'].values:
            print(f"Movie with ID {movie_id} not found in movies data.")
            return []

        # movie_index'i al
        movie_index = self.movies.index[self.movies['movieId'] == movie_id].tolist()[0]

        # Genre ve Tag similarity'lerini al
        genre_sim = self.genre_similarity[movie_index]
        tag_sim = self.tag_similarity[movie_index]

        # Ağırlıklı ortalama hesapla
        weighted_sim = (genre_sim * genre_weight) + (tag_sim * tag_weight)

        # En yüksek benzerlikteki filmleri seç (seçilen film hariç)
        similar_indices = weighted_sim.argsort()[-(num_recommendations+1):-1]  # En benzer olanları seç
        similar_movie_ids = self.movies.iloc[similar_indices]['movieId'].tolist()

        return similar_movie_ids

    def display_recommendations(self, recommended_movie_ids):
        if self.movies.empty:
            print("Movies data is empty. Cannot display recommendations.")
            return pd.DataFrame()

        if not recommended_movie_ids:
            print("No recommended movie IDs provided.")
            return pd.DataFrame()

        recommended_movies = self.movies[self.movies['movieId'].isin(recommended_movie_ids)]
        
        if recommended_movies.empty:
            print("No movies found for the provided movie IDs.")
            return pd.DataFrame()

        return recommended_movies[['title', 'genres']]

    def recommend_to_first_ten_users(self):
        all_recommendations = []
        
        # İlk 10 kullanıcıyı seç
        user_ids = self.user_movie_matrix.index[:10]  
        
        for user_id in user_ids:
            user_based_recommended_movie_ids = self.get_user_based_recommendations(user_id, num_recommendations=5)
            if user_based_recommended_movie_ids:
                recommended_movies_df = self.display_recommendations(user_based_recommended_movie_ids)
                if not recommended_movies_df.empty:
                    print(f"User ID: {user_id} (User-Based Recommendations)")
                    for _, row in recommended_movies_df.iterrows():
                        print(f"  - Title: {row['title']}, Genres: {row['genres']}")
                    for _, row in recommended_movies_df.iterrows():
                        all_recommendations.append({'userId': user_id, 'title': row['title'], 'genres': row['genres']})

                # Ağırlıklı tür ve tag bazlı öneriler
                for movie_id in user_based_recommended_movie_ids:
                    weighted_recommended_movie_ids = self.get_weighted_recommendations(movie_id, genre_weight=0.7, tag_weight=0.3, num_recommendations=5)
                    if weighted_recommended_movie_ids:
                        recommended_movies_df = self.display_recommendations(weighted_recommended_movie_ids)
                        if not recommended_movies_df.empty:
                            print(f"User ID: {user_id} (Weighted Genre+Tag-Based Recommendations for Movie ID: {movie_id})")
                            for _, row in recommended_movies_df.iterrows():
                                print(f"  - Title: {row['title']}, Genres: {row['genres']}")
                            for _, row in recommended_movies_df.iterrows():
                                all_recommendations.append({'userId': user_id, 'title': row['title'], 'genres': row['genres']})

        # Sonuçları DataFrame'e dönüştür
        recommendations_df = pd.DataFrame(all_recommendations)

        if not recommendations_df.empty:
            print("\nAll Recommendations for the first ten users:")
            print(recommendations_df)
        else:
            print("No recommendations generated for any of the first ten users.")

if __name__ == "__main__":
    movies_path = 'movies.csv'  # MovieLens filmleri
    ratings_path = 'ratings.csv'  # Kullanıcı puanları
    tags_path = 'tags.csv'  # Etiketler

    recommender = MovieRecommendationSystem(movies_path, ratings_path, tags_path)
    recommender.preprocess_data()
    recommender.train_model()

    # İlk on kullanıcı için öneri alma
    recommender.recommend_to_first_ten_users()
# Out:
# Movies data loaded. Shape: (9125, 3)
# Ratings data loaded. Shape: (100004, 4)
# Tags data loaded. Shape: (1296, 4)
# User-movie matrix created. Shape: (671, 9066)
# Tag-based similarity matrix created.
# Genre-based similarity matrix created.
# Model trained successfully.
# User ID: 1 (User-Based Recommendations)
#   - Title: Walk in the Clouds, A (1995), Genres: Drama|Romance
#   - Title: National Lampoon's Senior Trip (1995), Genres: Comedy
#   - Title: Double Happiness (1994), Genres: Drama
# User ID: 1 (Weighted Genre+Tag-Based Recommendations for Movie ID: 325)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# Movie with ID 634 not found in movies data.
# User ID: 1 (Weighted Genre+Tag-Based Recommendations for Movie ID: 341)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# Movie with ID 310 not found in movies data.
# User ID: 1 (Weighted Genre+Tag-Based Recommendations for Movie ID: 207)
#   - Title: Lovers on the Bridge, The (Amants du Pont-Neuf, Les) (1991), Genres: Drama|Romance
#   - Title: Ryan's Daughter (1970), Genres: Drama|Romance
#   - Title: Cinderella Man (2005), Genres: Drama|Romance
#   - Title: Last Chance Harvey (2008), Genres: Drama|Romance
#   - Title: Take This Waltz (2011), Genres: Drama|Romance
# User ID: 2 (User-Based Recommendations)
#   - Title: Rob Roy (1995), Genres: Action|Drama|Romance|War
#   - Title: Virtuosity (1995), Genres: Action|Sci-Fi|Thriller
#   - Title: Mrs. Parker and the Vicious Circle (1994), Genres: Drama
# User ID: 2 (Weighted Genre+Tag-Based Recommendations for Movie ID: 338)
#   - Title: Lawnmower Man 2: Beyond Cyberspace (1996), Genres: Action|Sci-Fi|Thriller
#   - Title: Outland (1981), Genres: Action|Sci-Fi|Thriller
#   - Title: Cypher (2002), Genres: Action|Sci-Fi|Thriller
#   - Title: Gamer (2009), Genres: Action|Sci-Fi|Thriller
#   - Title: Surrogates (2009), Genres: Action|Sci-Fi|Thriller
# User ID: 2 (Weighted Genre+Tag-Based Recommendations for Movie ID: 369)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 2 (Weighted Genre+Tag-Based Recommendations for Movie ID: 151)
#   - Title: Rob Roy (1995), Genres: Action|Drama|Romance|War
#   - Title: Spartacus (1960), Genres: Action|Drama|Romance|War
#   - Title: Flying Tigers (1942), Genres: Action|Drama|Romance|War
#   - Title: Pearl Harbor (2001), Genres: Action|Drama|Romance|War
#   - Title: Kingdom of Heaven (2005), Genres: Action|Drama|Romance|War
# Movie with ID 400 not found in movies data.
# Movie with ID 385 not found in movies data.
# User ID: 3 (User-Based Recommendations)
#   - Title: Beautiful Girls (1996), Genres: Comedy|Drama|Romance
#   - Title: Amazing Panda Adventure, The (1995), Genres: Adventure|Children
#   - Title: Timecop (1994), Genres: Action|Sci-Fi|Thriller
#   - Title: Geronimo: An American Legend (1993), Genres: Drama|Western
#   - Title: Radioland Murders (1994), Genres: Comedy|Mystery|Romance
# User ID: 3 (Weighted Genre+Tag-Based Recommendations for Movie ID: 379)
#   - Title: Lawnmower Man 2: Beyond Cyberspace (1996), Genres: Action|Sci-Fi|Thriller
#   - Title: Outland (1981), Genres: Action|Sci-Fi|Thriller
#   - Title: Cypher (2002), Genres: Action|Sci-Fi|Thriller
#   - Title: Gamer (2009), Genres: Action|Sci-Fi|Thriller
#   - Title: Surrogates (2009), Genres: Action|Sci-Fi|Thriller
# User ID: 3 (Weighted Genre+Tag-Based Recommendations for Movie ID: 146)
#   - Title: Alaska (1996), Genres: Adventure|Children
#   - Title: Fly Away Home (1996), Genres: Adventure|Children
#   - Title: Barney's Great Adventure (1998), Genres: Adventure|Children
#   - Title: Cheetah (1989), Genres: Adventure|Children
#   - Title: Treasure Island (1950), Genres: Adventure|Children
# User ID: 3 (Weighted Genre+Tag-Based Recommendations for Movie ID: 513)
#   - Title: Daytrippers, The (1996), Genres: Comedy|Drama|Mystery|Romance
#   - Title: They Might Be Giants (1971), Genres: Comedy|Mystery|Romance
#   - Title: Passion of Mind (2000), Genres: Drama|Mystery|Romance
#   - Title: Avventura, L' (Adventure, The) (1960), Genres: Drama|Mystery|Romance
#   - Title: Past, The (Le passé) (2013), Genres: Drama|Mystery|Romance
# User ID: 3 (Weighted Genre+Tag-Based Recommendations for Movie ID: 94)
#   - Title: Nobody's Fool (1994), Genres: Comedy|Drama|Romance
#   - Title: Philadelphia Story, The (1940), Genres: Comedy|Drama|Romance
#   - Title: Bossa Nova (2000), Genres: Comedy|Drama|Romance
#   - Title: Proof (1991), Genres: Comedy|Drama|Romance
#   - Title: Spanglish (2004), Genres: Comedy|Drama|Romance
# User ID: 3 (Weighted Genre+Tag-Based Recommendations for Movie ID: 458)
#   - Title: Unforgiven (1992), Genres: Drama|Western
#   - Title: Searchers, The (1956), Genres: Drama|Western
#   - Title: Shootist, The (1976), Genres: Drama|Western
#   - Title: Johnny Guitar (1954), Genres: Drama|Western
#   - Title: Antonio das Mortes (O Dragão da Maldade contra o Santo Guerreiro) (1969), Genres: Drama|Western
# User ID: 4 (User-Based Recommendations)
#   - Title: Angela (1995), Genres: Drama
#   - Title: Little Odessa (1994), Genres: Crime|Drama
#   - Title: Beyond Bedlam (1993), Genres: Drama|Horror
#   - Title: Hot Shots! Part Deux (1993), Genres: Action|Comedy|War
#   - Title: Road to Wellville, The (1994), Genres: Comedy
# User ID: 4 (Weighted Genre+Tag-Based Recommendations for Movie ID: 518)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# User ID: 4 (Weighted Genre+Tag-Based Recommendations for Movie ID: 130)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 4 (Weighted Genre+Tag-Based Recommendations for Movie ID: 466)
#   - Title: Hot Shots! Part Deux (1993), Genres: Action|Comedy|War
#   - Title: Iron Eagle II (1988), Genres: Action|War
#   - Title: Uncommon Valor (1983), Genres: Action|War
#   - Title: Guadalcanal Diary (1943), Genres: Action|War
#   - Title: Flight of the Intruder (1991), Genres: Action|War
# User ID: 4 (Weighted Genre+Tag-Based Recommendations for Movie ID: 285)
#   - Title: Needful Things (1993), Genres: Drama|Horror
#   - Title: Shadow of the Vampire (2000), Genres: Drama|Horror
#   - Title: My Son, My Son, What Have Ye Done (2009), Genres: Drama|Horror
#   - Title: Mark of the Devil (Hexen bis aufs Blut gequält) (1970), Genres: Drama|Horror
#   - Title: The Gift (2015), Genres: Drama|Horror
# User ID: 4 (Weighted Genre+Tag-Based Recommendations for Movie ID: 268)
#   - Title: Papillon (1973), Genres: Crime|Drama
#   - Title: Quai des Orfèvres (Jenny Lamour) (1947), Genres: Crime|Drama
#   - Title: Virgin Spring, The (Jungfrukällan) (1960), Genres: Crime|Drama
#   - Title: Maria Full of Grace (Maria, Llena eres de gracia) (2004), Genres: Crime|Drama
#   - Title: Boy A (2007), Genres: Crime|Drama
# User ID: 5 (User-Based Recommendations)
#   - Title: Outbreak (1995), Genres: Action|Drama|Sci-Fi|Thriller
#   - Title: Swan Princess, The (1994), Genres: Animation|Children
#   - Title: Demolition Man (1993), Genres: Action|Adventure|Sci-Fi
#   - Title: Mrs. Doubtfire (1993), Genres: Comedy|Drama
# User ID: 5 (Weighted Genre+Tag-Based Recommendations for Movie ID: 313)
#   - Title: Aristocats, The (1970), Genres: Animation|Children
#   - Title: Doug's 1st Movie (1999), Genres: Animation|Children
#   - Title: Batman: Mask of the Phantasm (1993), Genres: Animation|Children
#   - Title: Boundin' (2003), Genres: Animation|Children
#   - Title: Geri's Game (1997), Genres: Animation|Children
# User ID: 5 (Weighted Genre+Tag-Based Recommendations for Movie ID: 500)
#   - Title: Swimming with Sharks (1995), Genres: Comedy|Drama
#   - Title: Sum of Us, The (1994), Genres: Comedy|Drama
#   - Title: Auntie Mame (1958), Genres: Comedy|Drama
#   - Title: Last American Virgin, The (1982), Genres: Comedy|Drama
#   - Title: Offside (2006), Genres: Comedy|Drama
# User ID: 5 (Weighted Genre+Tag-Based Recommendations for Movie ID: 292)
#   - Title: Outbreak (1995), Genres: Action|Drama|Sci-Fi|Thriller
#   - Title: Impostor (2002), Genres: Action|Drama|Sci-Fi|Thriller
#   - Title: Star Trek: Nemesis (2002), Genres: Action|Drama|Sci-Fi|Thriller
#   - Title: Battlestar Galactica: Razor (2007), Genres: Action|Drama|Sci-Fi|Thriller
#   - Title: Doomsday (2008), Genres: Action|Drama|Sci-Fi|Thriller
# User ID: 5 (Weighted Genre+Tag-Based Recommendations for Movie ID: 442)
#   - Title: Star Wars: Episode I - The Phantom Menace (1999), Genres: Action|Adventure|Sci-Fi
#   - Title: X-Men (2000), Genres: Action|Adventure|Sci-Fi
#   - Title: Jupiter Ascending (2015), Genres: Action|Adventure|Sci-Fi
#   - Title: Star Trek 3 (2016), Genres: Action|Adventure|Sci-Fi
#   - Title: Robot Overlords (2014), Genres: Action|Adventure|Sci-Fi
# Movie with ID 654 not found in movies data.
# User ID: 6 (User-Based Recommendations)
#   - Title: Billy Madison (1995), Genres: Comedy
#   - Title: Losing Isaiah (1995), Genres: Drama
#   - Title: Red Firecracker, Green Firecracker (Pao Da Shuang Deng) (1994), Genres: Drama
#   - Title: Adventures of Priscilla, Queen of the Desert, The (1994), Genres: Comedy|Drama
#   - Title: Princess Caraboo (1994), Genres: Drama
# User ID: 6 (Weighted Genre+Tag-Based Recommendations for Movie ID: 345)
#   - Title: Swimming with Sharks (1995), Genres: Comedy|Drama
#   - Title: Sum of Us, The (1994), Genres: Comedy|Drama
#   - Title: Auntie Mame (1958), Genres: Comedy|Drama
#   - Title: Last American Virgin, The (1982), Genres: Comedy|Drama
#   - Title: Offside (2006), Genres: Comedy|Drama
# User ID: 6 (Weighted Genre+Tag-Based Recommendations for Movie ID: 309)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 6 (Weighted Genre+Tag-Based Recommendations for Movie ID: 580)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 6 (Weighted Genre+Tag-Based Recommendations for Movie ID: 216)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# User ID: 6 (Weighted Genre+Tag-Based Recommendations for Movie ID: 271)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 7 (User-Based Recommendations)
#   - Title: Get Shorty (1995), Genres: Comedy|Crime|Thriller
#   - Title: Ace Ventura: Pet Detective (1994), Genres: Comedy
#   - Title: Faster Pussycat! Kill! Kill! (1965), Genres: Action|Crime|Drama
#   - Title: Ref, The (1994), Genres: Comedy
#   - Title: Bye Bye, Love (1995), Genres: Comedy
# User ID: 7 (Weighted Genre+Tag-Based Recommendations for Movie ID: 21)
#   - Title: Man Who Knew Too Little, The (1997), Genres: Comedy|Crime|Thriller
#   - Title: Dead Men Don't Wear Plaid (1982), Genres: Comedy|Crime|Thriller
#   - Title: Snatch (2000), Genres: Comedy|Crime|Thriller
#   - Title: Shock to the System, A (1990), Genres: Comedy|Crime|Thriller
#   - Title: War, Inc. (2008), Genres: Comedy|Crime|Thriller
# User ID: 7 (Weighted Genre+Tag-Based Recommendations for Movie ID: 603)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# User ID: 7 (Weighted Genre+Tag-Based Recommendations for Movie ID: 514)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# User ID: 7 (Weighted Genre+Tag-Based Recommendations for Movie ID: 344)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# User ID: 7 (Weighted Genre+Tag-Based Recommendations for Movie ID: 390)
#   - Title: Menace II Society (1993), Genres: Action|Crime|Drama
#   - Title: Substitute, The (1996), Genres: Action|Crime|Drama
#   - Title: Death Wish (1974), Genres: Action|Crime|Drama
#   - Title: Black Rain (1989), Genres: Action|Crime|Drama
#   - Title: Gangster Squad (2013), Genres: Action|Crime|Drama
# User ID: 8 (User-Based Recommendations)
#   - Title: Billy Madison (1995), Genres: Comedy
#   - Title: Nell (1994), Genres: Drama
#   - Title: Timecop (1994), Genres: Action|Sci-Fi|Thriller
#   - Title: Robin Hood: Men in Tights (1993), Genres: Comedy
#   - Title: Welcome to the Dollhouse (1995), Genres: Comedy|Drama
# User ID: 8 (Weighted Genre+Tag-Based Recommendations for Movie ID: 520)
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Boat Trip (2003), Genres: Comedy
#   - Title: Role Models (2008), Genres: Comedy
#   - Title: Yes Man (2008), Genres: Comedy
# User ID: 8 (Weighted Genre+Tag-Based Recommendations for Movie ID: 216)
#   - Title: Porky's (1982), Genres: Comedy
#   - Title: Porky's II: The Next Day (1983), Genres: Comedy
#   - Title: Porky's Revenge (1985), Genres: Comedy
#   - Title: Bringing Down the House (2003), Genres: Comedy
#   - Title: Cedar Rapids (2011), Genres: Comedy
# User ID: 8 (Weighted Genre+Tag-Based Recommendations for Movie ID: 562)
#   - Title: Swimming with Sharks (1995), Genres: Comedy|Drama
#   - Title: Sum of Us, The (1994), Genres: Comedy|Drama
#   - Title: Auntie Mame (1958), Genres: Comedy|Drama
#   - Title: Last American Virgin, The (1982), Genres: Comedy|Drama
#   - Title: Offside (2006), Genres: Comedy|Drama
# User ID: 8 (Weighted Genre+Tag-Based Recommendations for Movie ID: 379)
#   - Title: Lawnmower Man 2: Beyond Cyberspace (1996), Genres: Action|Sci-Fi|Thriller
#   - Title: Outland (1981), Genres: Action|Sci-Fi|Thriller
#   - Title: Cypher (2002), Genres: Action|Sci-Fi|Thriller
#   - Title: Gamer (2009), Genres: Action|Sci-Fi|Thriller
#   - Title: Surrogates (2009), Genres: Action|Sci-Fi|Thriller
# User ID: 8 (Weighted Genre+Tag-Based Recommendations for Movie ID: 282)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 9 (User-Based Recommendations)
#   - Title: Now and Then (1995), Genres: Children|Drama
#   - Title: Bed of Roses (1996), Genres: Drama|Romance
#   - Title: Welcome to the Dollhouse (1995), Genres: Comedy|Drama
#   - Title: World of Apu, The (Apur Sansar) (1959), Genres: Drama
# User ID: 9 (Weighted Genre+Tag-Based Recommendations for Movie ID: 670)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 9 (Weighted Genre+Tag-Based Recommendations for Movie ID: 27)
#   - Title: Little Princess, A (1995), Genres: Children|Drama
#   - Title: My Dog Skip (1999), Genres: Children|Drama
#   - Title: National Velvet (1944), Genres: Children|Drama
#   - Title: Black Beauty (1971), Genres: Children|Drama
#   - Title: Son of Lassie (1945), Genres: Children|Drama
# Movie with ID 658 not found in movies data.
# User ID: 9 (Weighted Genre+Tag-Based Recommendations for Movie ID: 74)
#   - Title: Lovers on the Bridge, The (Amants du Pont-Neuf, Les) (1991), Genres: Drama|Romance
#   - Title: Ryan's Daughter (1970), Genres: Drama|Romance
#   - Title: Cinderella Man (2005), Genres: Drama|Romance
#   - Title: Last Chance Harvey (2008), Genres: Drama|Romance
#   - Title: Take This Waltz (2011), Genres: Drama|Romance
# User ID: 9 (Weighted Genre+Tag-Based Recommendations for Movie ID: 562)
#   - Title: Swimming with Sharks (1995), Genres: Comedy|Drama
#   - Title: Sum of Us, The (1994), Genres: Comedy|Drama
#   - Title: Auntie Mame (1958), Genres: Comedy|Drama
#   - Title: Last American Virgin, The (1982), Genres: Comedy|Drama
#   - Title: Offside (2006), Genres: Comedy|Drama
# User ID: 10 (User-Based Recommendations)
#   - Title: Beyond Rangoon (1995), Genres: Adventure|Drama|War
#   - Title: Unzipped (1995), Genres: Documentary
#   - Title: Losing Isaiah (1995), Genres: Drama
#   - Title: Threesome (1994), Genres: Comedy|Romance
#   - Title: Welcome to the Dollhouse (1995), Genres: Comedy|Drama
# User ID: 10 (Weighted Genre+Tag-Based Recommendations for Movie ID: 271)
#   - Title: That's Life! (1986), Genres: Drama
#   - Title: Woman Under the Influence, A (1974), Genres: Drama
#   - Title: Jezebel (1938), Genres: Drama
#   - Title: Frost/Nixon (2008), Genres: Drama
#   - Title: This Is 40 (2012), Genres: Drama
# User ID: 10 (Weighted Genre+Tag-Based Recommendations for Movie ID: 155)
#   - Title: Beyond Rangoon (1995), Genres: Adventure|Drama|War
#   - Title: Bridge on the River Kwai, The (1957), Genres: Adventure|Drama|War
#   - Title: Seven Years in Tibet (1997), Genres: Adventure|Drama|War
#   - Title: Blue Max, The (1966), Genres: Adventure|Drama|War
#   - Title: Master and Commander: The Far Side of the World (2003), Genres: Adventure|Drama|War
# User ID: 10 (Weighted Genre+Tag-Based Recommendations for Movie ID: 206)
#   - Title: Year of the Horse (1997), Genres: Documentary
#   - Title: Waiting for 'Superman' (2010), Genres: Documentary
#   - Title: Agony and the Ecstasy of Phil Spector, The (2009), Genres: Documentary
#   - Title: Art of the Steal, The (2009), Genres: Documentary
#   - Title: Tillman Story, The (2010), Genres: Documentary
# User ID: 10 (Weighted Genre+Tag-Based Recommendations for Movie ID: 562)
#   - Title: Swimming with Sharks (1995), Genres: Comedy|Drama
#   - Title: Sum of Us, The (1994), Genres: Comedy|Drama
#   - Title: Auntie Mame (1958), Genres: Comedy|Drama
#   - Title: Last American Virgin, The (1982), Genres: Comedy|Drama
#   - Title: Offside (2006), Genres: Comedy|Drama
# User ID: 10 (Weighted Genre+Tag-Based Recommendations for Movie ID: 550)
#   - Title: Never Been Kissed (1999), Genres: Comedy|Romance
#   - Title: Princess Diaries 2: Royal Engagement, The (2004), Genres: Comedy|Romance
#   - Title: Gerontophilia (2013), Genres: Comedy|Romance
#   - Title: About Last Night (2014), Genres: Comedy|Romance
#   - Title: That Awkward Moment (2014), Genres: Comedy|Romance
#
# All Recommendations for the first ten users:
#      userId                                             title          genres
# 0         1                      Walk in the Clouds, A (1995)   Drama|Romance
# 1         1             National Lampoon's Senior Trip (1995)          Comedy
# 2         1                           Double Happiness (1994)           Drama
# 3         1                                    Porky's (1982)          Comedy
# 4         1                   Porky's II: The Next Day (1983)          Comedy
# ..      ...                                               ...             ...
# 259      10                          Never Been Kissed (1999)  Comedy|Romance
# 260      10  Princess Diaries 2: Royal Engagement, The (2004)  Comedy|Romance
# 261      10                              Gerontophilia (2013)  Comedy|Romance
# 262      10                           About Last Night (2014)  Comedy|Romance
# 263      10                        That Awkward Moment (2014)  Comedy|Romance
#
# [264 rows x 3 columns]
